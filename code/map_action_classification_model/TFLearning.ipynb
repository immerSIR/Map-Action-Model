# %%
import os
import numpy as np
import torch
from glob import glob
import torch.nn as nn
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
from torchvision.models import vgg16_bn, VGG16_BN_Weights
from matplotlib import pyplot as plt

# %%
vgg16_bn_weights = VGG16_BN_Weights.DEFAULT
model = vgg16_bn(weights=vgg16_bn_weights)
transform = vgg16_bn_weights.transforms
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to C:\Users\Wakfu/.cache\torch\hub\checkpoints\vgg16_bn-6c64b313.pth
# 100%|██████████| 528M/528M [02:06<00:00, 4.37MB/s]

# %%
def create_dataloaders(train_dir, valid_dir, test_dir, transform, batch_size, num_workers):
    
    # Use ImageFolder to create dataset(s)
    train_data = datasets.ImageFolder(train_dir, transform=transform)
    valid_data = datasets.ImageFolder(valid_dir, transform=transform)
    test_data = datasets.ImageFolder(test_dir, transform=transform)
    
    # Get class names
    class_names = train_data.classes
    
    # Turn images into data loaders
    training_dataloader = DataLoader(
        train_data,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True,
    )
    
    validation_dataloader = DataLoader(
        valid_data,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True,
    )
    
    testing_dataloader = DataLoader(
        test_data,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )
    
    return training_dataloader, testing_dataloader, class_names

# %%
path = 'data/'
types = ('*.jpg', '*.jpeg', '*.png')
files = []
for ext in types:
    f = glob(os.path.join(path, '*/'+ext))
    files += f
    
(files)
# Out:
# ['data\\Cyclone\\0.jpg',
#  'data\\Cyclone\\1.jpg',
#  'data\\Cyclone\\10.jpg',
#  'data\\Cyclone\\100.jpg',
#  'data\\Cyclone\\101.jpg',
#  'data\\Cyclone\\102.jpg',
#  'data\\Cyclone\\103.jpg',
#  'data\\Cyclone\\104.jpg',
#  'data\\Cyclone\\105.jpg',
#  'data\\Cyclone\\106.jpg',
#  'data\\Cyclone\\107.jpg',
#  'data\\Cyclone\\108.jpg',
#  'data\\Cyclone\\109.jpg',
#  'data\\Cyclone\\11.jpg',
#  'data\\Cyclone\\110.jpg',
#  'data\\Cyclone\\111.jpg',
#  'data\\Cyclone\\112.jpg',
#  'data\\Cyclone\\113.jpg',
#  'data\\Cyclone\\114.jpg',
#  'data\\Cyclone\\115.jpg',
#  'data\\Cyclone\\116.jpg',
#  'data\\Cyclone\\117.jpg',
#  'data\\Cyclone\\118.jpg',
#  'data\\Cyclone\\119.jpg',
#  'data\\Cyclone\\12.jpg',
#  'data\\Cyclone\\120.jpg',
#  'data\\Cyclone\\121.jpg',
#  'data\\Cyclone\\122.jpg',
#  'data\\Cyclone\\123.jpg',
#  'data\\Cyclone\\124.jpg',
#  'data\\Cyclone\\125.jpg',
#  'data\\Cyclone\\126.jpg',
#  'data\\Cyclone\\127.jpg',
#  'data\\Cyclone\\128.jpg',
#  'data\\Cyclone\\129.jpg',
#  'data\\Cyclone\\13.jpg',
#  'data\\Cyclone\\130.jpg',
#  'data\\Cyclone\\131.jpg',
#  'data\\Cyclone\\132.jpg',
#  'data\\Cyclone\\133.jpg',
#  'data\\Cyclone\\134.jpg',
#  'data\\Cyclone\\135.jpg',
#  'data\\Cyclone\\136.jpg',
#  'data\\Cyclone\\137.jpg',
#  'data\\Cyclone\\138.jpg',
#  'data\\Cyclone\\139.jpg',
#  'data\\Cyclone\\14.jpg',
#  'data\\Cyclone\\140.jpg',
#  'data\\Cyclone\\141.jpg',
#  'data\\Cyclone\\142.jpg',
#  'data\\Cyclone\\143.jpg',
#  'data\\Cyclone\\144.jpg',
#  'data\\Cyclone\\145.jpg',
#  'data\\Cyclone\\146.jpg',
#  'data\\Cyclone\\147.jpg',
#  'data\\Cyclone\\148.jpg',
#  'data\\Cyclone\\149.jpg',
#  'data\\Cyclone\\15.jpg',
#  'data\\Cyclone\\150.jpg',
#  'data\\Cyclone\\151.jpg',
#  'data\\Cyclone\\152.jpg',
#  'data\\Cyclone\\153.jpg',
#  'data\\Cyclone\\154.jpg',
#  'data\\Cyclone\\155.jpg',
#  'data\\Cyclone\\156.jpg',
#  'data\\Cyclone\\157.jpg',
#  'data\\Cyclone\\158.jpg',
#  'data\\Cyclone\\159.jpg',
#  'data\\Cyclone\\16.jpg',
#  'data\\Cyclone\\160.jpg',
#  'data\\Cyclone\\161.jpg',
#  'data\\Cyclone\\162.jpg',
#  'data\\Cyclone\\163.jpg',
#  'data\\Cyclone\\164.jpg',
#  'data\\Cyclone\\165.jpg',
#  'data\\Cyclone\\166.jpg',
#  'data\\Cyclone\\167.jpg',
#  'data\\Cyclone\\168.jpg',
#  'data\\Cyclone\\169.jpg',
#  'data\\Cyclone\\17.jpg',
#  'data\\Cyclone\\170.jpg',
#  'data\\Cyclone\\171.jpg',
#  'data\\Cyclone\\172.jpg',
#  'data\\Cyclone\\173.jpg',
#  'data\\Cyclone\\174.jpg',
#  'data\\Cyclone\\175.jpg',
#  'data\\Cyclone\\176.jpg',
#  'data\\Cyclone\\177.jpg',
#  'data\\Cyclone\\178.jpg',
#  'data\\Cyclone\\179.jpg',
#  'data\\Cyclone\\18.jpg',
#  'data\\Cyclone\\180.jpg',
#  'data\\Cyclone\\181.jpg',
#  'data\\Cyclone\\182.jpg',
#  'data\\Cyclone\\183.jpg',
#  'data\\Cyclone\\184.jpg',
#  'data\\Cyclone\\185.jpg',
#  'data\\Cyclone\\186.jpg',
#  'data\\Cyclone\\187.jpg',
#  'data\\Cyclone\\188.jpg',
#  'data\\Cyclone\\189.jpg',
#  'data\\Cyclone\\19.jpg',
#  'data\\Cyclone\\190.jpg',
#  'data\\Cyclone\\191.jpg',
#  'data\\Cyclone\\192.jpg',
#  'data\\Cyclone\\193.jpg',
#  'data\\Cyclone\\194.jpg',
#  'data\\Cyclone\\195.jpg',
#  'data\\Cyclone\\196.jpg',
#  'data\\Cyclone\\197.jpg',
#  'data\\Cyclone\\198.jpg',
#  'data\\Cyclone\\199.jpg',
#  'data\\Cyclone\\2.jpg',
#  'data\\Cyclone\\20.jpg',
#  'data\\Cyclone\\200.jpg',
#  'data\\Cyclone\\201.jpg',
#  'data\\Cyclone\\202.jpg',
#  'data\\Cyclone\\203.jpg',
#  'data\\Cyclone\\204.jpg',
#  'data\\Cyclone\\205.jpg',
#  'data\\Cyclone\\206.jpg',
#  'data\\Cyclone\\207.jpg',
#  'data\\Cyclone\\208.jpg',
#  'data\\Cyclone\\209.jpg',
#  'data\\Cyclone\\21.jpg',
#  'data\\Cyclone\\210.jpg',
#  'data\\Cyclone\\211.jpg',
#  'data\\Cyclone\\212.jpg',
#  'data\\Cyclone\\213.jpg',
#  'data\\Cyclone\\214.jpg',
#  'data\\Cyclone\\215.jpg',
#  'data\\Cyclone\\216.jpg',
#  'data\\Cyclone\\217.jpg',
#  'data\\Cyclone\\218.jpg',
#  'data\\Cyclone\\219.jpg',
#  'data\\Cyclone\\22.jpg',
#  'data\\Cyclone\\220.jpg',
#  'data\\Cyclone\\221.jpg',
#  'data\\Cyclone\\222.jpg',
#  'data\\Cyclone\\223.jpg',
#  'data\\Cyclone\\224.jpg',
#  'data\\Cyclone\\225.jpg',
#  'data\\Cyclone\\226.jpg',
#  'data\\Cyclone\\227.jpg',
#  'data\\Cyclone\\228.jpg',
#  'data\\Cyclone\\229.jpg',
#  'data\\Cyclone\\23.jpg',
#  'data\\Cyclone\\230.jpg',
#  'data\\Cyclone\\231.jpg',
#  'data\\Cyclone\\232.jpg',
#  'data\\Cyclone\\233.jpg',
#  'data\\Cyclone\\234.jpg',
#  'data\\Cyclone\\235.jpg',
#  'data\\Cyclone\\236.jpg',
#  'data\\Cyclone\\237.jpg',
#  'data\\Cyclone\\238.jpg',
#  'data\\Cyclone\\239.jpg',
#  'data\\Cyclone\\24.jpg',
#  'data\\Cyclone\\240.jpg',
#  'data\\Cyclone\\241.jpg',
#  'data\\Cyclone\\242.jpg',
#  'data\\Cyclone\\243.jpg',
#  'data\\Cyclone\\244.jpg',
#  'data\\Cyclone\\245.jpg',
#  'data\\Cyclone\\246.jpg',
#  'data\\Cyclone\\247.jpg',
#  'data\\Cyclone\\248.jpg',
#  'data\\Cyclone\\249.jpg',
#  'data\\Cyclone\\25.jpg',
#  'data\\Cyclone\\250.jpg',
#  'data\\Cyclone\\251.jpg',
#  'data\\Cyclone\\252.jpg',
#  'data\\Cyclone\\253.jpg',
#  'data\\Cyclone\\254.jpg',
#  'data\\Cyclone\\255.jpg',
#  'data\\Cyclone\\256.jpg',
#  'data\\Cyclone\\257.jpg',
#  'data\\Cyclone\\258.jpg',
#  'data\\Cyclone\\259.jpg',
#  'data\\Cyclone\\26.jpg',
#  'data\\Cyclone\\260.jpg',
#  'data\\Cyclone\\261.jpg',
#  'data\\Cyclone\\262.jpg',
#  'data\\Cyclone\\263.jpg',
#  'data\\Cyclone\\264.jpg',
#  'data\\Cyclone\\265.jpg',
#  'data\\Cyclone\\266.jpg',
#  'data\\Cyclone\\267.jpg',
#  'data\\Cyclone\\268.jpg',
#  'data\\Cyclone\\269.jpg',
#  'data\\Cyclone\\27.jpg',
#  'data\\Cyclone\\270.jpg',
#  'data\\Cyclone\\271.jpg',
#  'data\\Cyclone\\272.jpg',
#  'data\\Cyclone\\273.jpg',
#  'data\\Cyclone\\274.jpg',
#  'data\\Cyclone\\275.jpg',
#  'data\\Cyclone\\276.jpg',
#  'data\\Cyclone\\277.jpg',
#  'data\\Cyclone\\278.jpg',
#  'data\\Cyclone\\279.jpg',
#  'data\\Cyclone\\28.jpg',
#  'data\\Cyclone\\280.jpg',
#  'data\\Cyclone\\281.jpg',
#  'data\\Cyclone\\282.jpg',
#  'data\\Cyclone\\283.jpg',
#  'data\\Cyclone\\284.jpg',
#  'data\\Cyclone\\285.jpg',
#  'data\\Cyclone\\286.jpg',
#  'data\\Cyclone\\287.jpg',
#  'data\\Cyclone\\288.jpg',
#  'data\\Cyclone\\289.jpg',
#  'data\\Cyclone\\29.jpg',
#  'data\\Cyclone\\290.jpg',
#  'data\\Cyclone\\291.jpg',
#  'data\\Cyclone\\292.jpg',
#  'data\\Cyclone\\293.jpg',
#  'data\\Cyclone\\294.jpg',
#  'data\\Cyclone\\295.jpg',
#  'data\\Cyclone\\296.jpg',
#  'data\\Cyclone\\297.jpg',
#  'data\\Cyclone\\298.jpg',
#  'data\\Cyclone\\299.jpg',
#  'data\\Cyclone\\3.jpg',
#  'data\\Cyclone\\30.jpg',
#  'data\\Cyclone\\300.jpg',
#  'data\\Cyclone\\301.jpg',
#  'data\\Cyclone\\302.jpg',
#  'data\\Cyclone\\303.jpg',
#  'data\\Cyclone\\304.jpg',
#  'data\\Cyclone\\305.jpg',
#  'data\\Cyclone\\306.jpg',
#  'data\\Cyclone\\307.jpg',
#  'data\\Cyclone\\308.jpg',
#  'data\\Cyclone\\309.jpg',
#  'data\\Cyclone\\31.jpg',
#  'data\\Cyclone\\310.jpg',
#  'data\\Cyclone\\311.jpg',
#  'data\\Cyclone\\312.jpg',
#  'data\\Cyclone\\313.jpg',
#  'data\\Cyclone\\314.jpg',
#  'data\\Cyclone\\315.jpg',
#  'data\\Cyclone\\316.jpg',
#  'data\\Cyclone\\317.jpg',
#  'data\\Cyclone\\318.jpg',
#  'data\\Cyclone\\319.jpg',
#  'data\\Cyclone\\32.jpg',
#  'data\\Cyclone\\320.jpg',
#  'data\\Cyclone\\321.jpg',
#  'data\\Cyclone\\322.jpg',
#  'data\\Cyclone\\323.jpg',
#  'data\\Cyclone\\324.jpg',
#  'data\\Cyclone\\325.jpg',
#  'data\\Cyclone\\326.jpg',
#  'data\\Cyclone\\327.jpg',
#  'data\\Cyclone\\328.jpg',
#  'data\\Cyclone\\329.jpg',
#  'data\\Cyclone\\33.jpg',
#  'data\\Cyclone\\330.jpg',
#  'data\\Cyclone\\331.jpg',
#  'data\\Cyclone\\332.jpg',
#  'data\\Cyclone\\333.jpg',
#  'data\\Cyclone\\334.jpg',
#  'data\\Cyclone\\335.jpg',
#  'data\\Cyclone\\336.jpg',
#  'data\\Cyclone\\337.jpg',
#  'data\\Cyclone\\338.jpg',
#  'data\\Cyclone\\339.jpg',
#  'data\\Cyclone\\34.jpg',
#  'data\\Cyclone\\340.jpg',
#  'data\\Cyclone\\341.jpg',
#  'data\\Cyclone\\342.jpg',
#  'data\\Cyclone\\343.jpg',
#  'data\\Cyclone\\344.jpg',
#  'data\\Cyclone\\345.jpg',
#  'data\\Cyclone\\346.jpg',
#  'data\\Cyclone\\347.jpg',
#  'data\\Cyclone\\348.jpg',
#  'data\\Cyclone\\349.jpg',
#  'data\\Cyclone\\35.jpg',
#  'data\\Cyclone\\350.jpg',
#  'data\\Cyclone\\351.jpg',
#  'data\\Cyclone\\352.jpg',
#  'data\\Cyclone\\353.jpg',
#  'data\\Cyclone\\354.jpg',
#  'data\\Cyclone\\355.jpg',
#  'data\\Cyclone\\356.jpg',
#  'data\\Cyclone\\357.jpg',
#  'data\\Cyclone\\358.jpg',
#  'data\\Cyclone\\359.jpg',
#  'data\\Cyclone\\36.jpg',
#  'data\\Cyclone\\360.jpg',
#  'data\\Cyclone\\361.jpg',
#  'data\\Cyclone\\362.jpg',
#  'data\\Cyclone\\363.jpg',
#  'data\\Cyclone\\364.jpg',
#  'data\\Cyclone\\365.jpg',
#  'data\\Cyclone\\366.jpg',
#  'data\\Cyclone\\367.jpg',
#  'data\\Cyclone\\368.jpg',
#  'data\\Cyclone\\369.jpg',
#  'data\\Cyclone\\37.jpg',
#  'data\\Cyclone\\370.jpg',
#  'data\\Cyclone\\371.jpg',
#  'data\\Cyclone\\372.jpg',
#  'data\\Cyclone\\373.jpg',
#  'data\\Cyclone\\374.jpg',
#  'data\\Cyclone\\375.jpg',
#  'data\\Cyclone\\376.jpg',
#  'data\\Cyclone\\377.jpg',
#  'data\\Cyclone\\378.jpg',
#  'data\\Cyclone\\379.jpg',
#  'data\\Cyclone\\38.jpg',
#  'data\\Cyclone\\380.jpg',
#  'data\\Cyclone\\381.jpg',
#  'data\\Cyclone\\382.jpg',
#  'data\\Cyclone\\383.jpg',
#  'data\\Cyclone\\384.jpg',
#  'data\\Cyclone\\385.jpg',
#  'data\\Cyclone\\386.jpg',
#  'data\\Cyclone\\387.jpg',
#  'data\\Cyclone\\388.jpg',
#  'data\\Cyclone\\389.jpg',
#  'data\\Cyclone\\39.jpg',
#  'data\\Cyclone\\390.jpg',
#  'data\\Cyclone\\391.jpg',
#  'data\\Cyclone\\392.jpg',
#  'data\\Cyclone\\393.jpg',
#  'data\\Cyclone\\394.jpg',
#  'data\\Cyclone\\395.jpg',
#  'data\\Cyclone\\396.jpg',
#  'data\\Cyclone\\397.jpg',
#  'data\\Cyclone\\398.jpg',
#  'data\\Cyclone\\399.jpg',
#  'data\\Cyclone\\4.jpg',
#  'data\\Cyclone\\40.jpg',
#  'data\\Cyclone\\400.jpg',
#  'data\\Cyclone\\401.jpg',
#  'data\\Cyclone\\402.jpg',
#  'data\\Cyclone\\403.jpg',
#  'data\\Cyclone\\404.jpg',
#  'data\\Cyclone\\405.jpg',
#  'data\\Cyclone\\406.jpg',
#  'data\\Cyclone\\407.jpg',
#  'data\\Cyclone\\408.jpg',
#  'data\\Cyclone\\409.jpg',
#  'data\\Cyclone\\41.jpg',
#  'data\\Cyclone\\410.jpg',
#  'data\\Cyclone\\411.jpg',
#  'data\\Cyclone\\412.jpg',
#  'data\\Cyclone\\413.jpg',
#  'data\\Cyclone\\414.jpg',
#  'data\\Cyclone\\415.jpg',
#  'data\\Cyclone\\416.jpg',
#  'data\\Cyclone\\417.jpg',
#  'data\\Cyclone\\418.jpg',
#  'data\\Cyclone\\419.jpg',
#  'data\\Cyclone\\42.jpg',
#  'data\\Cyclone\\420.jpg',
#  'data\\Cyclone\\421.jpg',
#  'data\\Cyclone\\422.jpg',
#  'data\\Cyclone\\423.jpg',
#  'data\\Cyclone\\424.jpg',
#  'data\\Cyclone\\425.jpg',
#  'data\\Cyclone\\426.jpg',
#  'data\\Cyclone\\427.jpg',
#  'data\\Cyclone\\428.jpg',
#  'data\\Cyclone\\429.jpg',
#  'data\\Cyclone\\43.jpg',
#  'data\\Cyclone\\430.jpg',
#  'data\\Cyclone\\431.jpg',
#  'data\\Cyclone\\432.jpg',
#  'data\\Cyclone\\433.jpg',
#  'data\\Cyclone\\434.jpg',
#  'data\\Cyclone\\435.jpg',
#  'data\\Cyclone\\436.jpg',
#  'data\\Cyclone\\437.jpg',
#  'data\\Cyclone\\438.jpg',
#  'data\\Cyclone\\439.jpg',
#  'data\\Cyclone\\44.jpg',
#  'data\\Cyclone\\440.jpg',
#  'data\\Cyclone\\441.jpg',
#  'data\\Cyclone\\442.jpg',
#  'data\\Cyclone\\443.jpg',
#  'data\\Cyclone\\444.jpg',
#  'data\\Cyclone\\445.jpg',
#  'data\\Cyclone\\446.jpg',
#  'data\\Cyclone\\447.jpg',
#  'data\\Cyclone\\448.jpg',
#  'data\\Cyclone\\449.jpg',
#  'data\\Cyclone\\45.jpg',
#  'data\\Cyclone\\450.jpg',
#  'data\\Cyclone\\451.jpg',
#  'data\\Cyclone\\452.jpg',
#  'data\\Cyclone\\453.jpg',
#  'data\\Cyclone\\454.jpg',
#  'data\\Cyclone\\455.jpg',
#  'data\\Cyclone\\456.jpg',
#  'data\\Cyclone\\457.jpg',
#  'data\\Cyclone\\458.jpg',
#  'data\\Cyclone\\459.jpg',
#  'data\\Cyclone\\46.jpg',
#  'data\\Cyclone\\460.jpg',
#  'data\\Cyclone\\461.jpg',
#  'data\\Cyclone\\462.jpg',
#  'data\\Cyclone\\463.jpg',
#  'data\\Cyclone\\464.jpg',
#  'data\\Cyclone\\465.jpg',
#  'data\\Cyclone\\466.jpg',
#  'data\\Cyclone\\467.jpg',
#  'data\\Cyclone\\468.jpg',
#  'data\\Cyclone\\469.jpg',
#  'data\\Cyclone\\47.jpg',
#  'data\\Cyclone\\470.jpg',
#  'data\\Cyclone\\471.jpg',
#  'data\\Cyclone\\472.jpg',
#  'data\\Cyclone\\473.jpg',
#  'data\\Cyclone\\474.jpg',
#  'data\\Cyclone\\475.jpg',
#  'data\\Cyclone\\476.jpg',
#  'data\\Cyclone\\477.jpg',
#  'data\\Cyclone\\478.jpg',
#  'data\\Cyclone\\479.jpg',
#  'data\\Cyclone\\48.jpg',
#  'data\\Cyclone\\480.jpg',
#  'data\\Cyclone\\481.jpg',
#  'data\\Cyclone\\482.jpg',
#  'data\\Cyclone\\483.jpg',
#  'data\\Cyclone\\484.jpg',
#  'data\\Cyclone\\485.jpg',
#  'data\\Cyclone\\486.jpg',
#  'data\\Cyclone\\487.jpg',
#  'data\\Cyclone\\488.jpg',
#  'data\\Cyclone\\489.jpg',
#  'data\\Cyclone\\49.jpg',
#  'data\\Cyclone\\490.jpg',
#  'data\\Cyclone\\491.jpg',
#  'data\\Cyclone\\492.jpg',
#  'data\\Cyclone\\493.jpg',
#  'data\\Cyclone\\494.jpg',
#  'data\\Cyclone\\495.jpg',
#  'data\\Cyclone\\496.jpg',
#  'data\\Cyclone\\497.jpg',
#  'data\\Cyclone\\498.jpg',
#  'data\\Cyclone\\499.jpg',
#  'data\\Cyclone\\5.jpg',
#  'data\\Cyclone\\50.jpg',
#  'data\\Cyclone\\500.jpg',
#  'data\\Cyclone\\501.jpg',
#  'data\\Cyclone\\502.jpg',
#  'data\\Cyclone\\503.jpg',
#  'data\\Cyclone\\504.jpg',
#  'data\\Cyclone\\505.jpg',
#  'data\\Cyclone\\506.jpg',
#  'data\\Cyclone\\507.jpg',
#  'data\\Cyclone\\508.jpg',
#  'data\\Cyclone\\509.jpg',
#  'data\\Cyclone\\51.jpg',
#  'data\\Cyclone\\510.jpg',
#  'data\\Cyclone\\511.jpg',
#  'data\\Cyclone\\512.jpg',
#  'data\\Cyclone\\513.jpg',
#  'data\\Cyclone\\514.jpg',
#  'data\\Cyclone\\515.jpg',
#  'data\\Cyclone\\516.jpg',
#  'data\\Cyclone\\517.jpg',
#  'data\\Cyclone\\518.jpg',
#  'data\\Cyclone\\519.jpg',
#  'data\\Cyclone\\52.jpg',
#  'data\\Cyclone\\520.jpg',
#  'data\\Cyclone\\521.jpg',
#  'data\\Cyclone\\522.jpg',
#  'data\\Cyclone\\523.jpg',
#  'data\\Cyclone\\524.jpg',
#  'data\\Cyclone\\525.jpg',
#  'data\\Cyclone\\526.jpg',
#  'data\\Cyclone\\527.jpg',
#  'data\\Cyclone\\528.jpg',
#  'data\\Cyclone\\529.jpg',
#  'data\\Cyclone\\53.jpg',
#  'data\\Cyclone\\530.jpg',
#  'data\\Cyclone\\531.jpg',
#  'data\\Cyclone\\532.jpg',
#  'data\\Cyclone\\533.jpg',
#  'data\\Cyclone\\534.jpg',
#  'data\\Cyclone\\535.jpg',
#  'data\\Cyclone\\536.jpg',
#  'data\\Cyclone\\537.jpg',
#  'data\\Cyclone\\538.jpg',
#  'data\\Cyclone\\539.jpg',
#  'data\\Cyclone\\54.jpg',
#  'data\\Cyclone\\540.jpg',
#  'data\\Cyclone\\541.jpg',
#  'data\\Cyclone\\542.jpg',
#  'data\\Cyclone\\543.jpg',
#  'data\\Cyclone\\544.jpg',
#  'data\\Cyclone\\545.jpg',
#  'data\\Cyclone\\546.jpg',
#  'data\\Cyclone\\547.jpg',
#  'data\\Cyclone\\548.jpg',
#  'data\\Cyclone\\549.jpg',
#  'data\\Cyclone\\55.jpg',
#  'data\\Cyclone\\550.jpg',
#  'data\\Cyclone\\551.jpg',
#  'data\\Cyclone\\552.jpg',
#  'data\\Cyclone\\553.jpg',
#  'data\\Cyclone\\554.jpg',
#  'data\\Cyclone\\555.jpg',
#  'data\\Cyclone\\556.jpg',
#  'data\\Cyclone\\557.jpg',
#  'data\\Cyclone\\558.jpg',
#  'data\\Cyclone\\559.jpg',
#  'data\\Cyclone\\56.jpg',
#  'data\\Cyclone\\560.jpg',
#  'data\\Cyclone\\561.jpg',
#  'data\\Cyclone\\562.jpg',
#  'data\\Cyclone\\563.jpg',
#  'data\\Cyclone\\564.jpg',
#  'data\\Cyclone\\565.jpg',
#  'data\\Cyclone\\566.jpg',
#  'data\\Cyclone\\567.jpg',
#  'data\\Cyclone\\568.jpg',
#  'data\\Cyclone\\569.jpg',
#  'data\\Cyclone\\57.jpg',
#  'data\\Cyclone\\570.jpg',
#  'data\\Cyclone\\571.jpg',
#  'data\\Cyclone\\572.jpg',
#  'data\\Cyclone\\573.jpg',
#  'data\\Cyclone\\574.jpg',
#  'data\\Cyclone\\575.jpg',
#  'data\\Cyclone\\576.jpg',
#  'data\\Cyclone\\577.jpg',
#  'data\\Cyclone\\578.jpg',
#  'data\\Cyclone\\579.jpg',
#  'data\\Cyclone\\58.jpg',
#  'data\\Cyclone\\580.jpg',
#  'data\\Cyclone\\581.jpg',
#  'data\\Cyclone\\582.jpg',
#  'data\\Cyclone\\583.jpg',
#  'data\\Cyclone\\584.jpg',
#  'data\\Cyclone\\585.jpg',
#  'data\\Cyclone\\586.jpg',
#  'data\\Cyclone\\587.jpg',
#  'data\\Cyclone\\588.jpg',
#  'data\\Cyclone\\589.jpg',
#  'data\\Cyclone\\59.jpg',
#  'data\\Cyclone\\590.jpg',
#  'data\\Cyclone\\591.jpg',
#  'data\\Cyclone\\592.jpg',
#  'data\\Cyclone\\593.jpg',
#  'data\\Cyclone\\594.jpg',
#  'data\\Cyclone\\595.jpg',
#  'data\\Cyclone\\596.jpg',
#  'data\\Cyclone\\597.jpg',
#  'data\\Cyclone\\598.jpg',
#  'data\\Cyclone\\599.jpg',
#  'data\\Cyclone\\6.jpg',
#  'data\\Cyclone\\60.jpg',
#  'data\\Cyclone\\600.jpg',
#  'data\\Cyclone\\601.jpg',
#  'data\\Cyclone\\602.jpg',
#  'data\\Cyclone\\603.jpg',
#  'data\\Cyclone\\604.jpg',
#  'data\\Cyclone\\605.jpg',
#  'data\\Cyclone\\606.jpg',
#  'data\\Cyclone\\607.jpg',
#  'data\\Cyclone\\608.jpg',
#  'data\\Cyclone\\609.jpg',
#  'data\\Cyclone\\61.jpg',
#  'data\\Cyclone\\610.jpg',
#  'data\\Cyclone\\611.jpg',
#  'data\\Cyclone\\612.jpg',
#  'data\\Cyclone\\613.jpg',
#  'data\\Cyclone\\614.jpg',
#  'data\\Cyclone\\615.jpg',
#  'data\\Cyclone\\616.jpg',
#  'data\\Cyclone\\617.jpg',
#  'data\\Cyclone\\618.jpg',
#  'data\\Cyclone\\619.jpg',
#  'data\\Cyclone\\62.jpg',
#  'data\\Cyclone\\620.jpg',
#  'data\\Cyclone\\621.jpg',
#  'data\\Cyclone\\622.jpg',
#  'data\\Cyclone\\623.jpg',
#  'data\\Cyclone\\624.jpg',
#  'data\\Cyclone\\625.jpg',
#  'data\\Cyclone\\626.jpg',
#  'data\\Cyclone\\627.jpg',
#  'data\\Cyclone\\628.jpg',
#  'data\\Cyclone\\629.jpg',
#  'data\\Cyclone\\63.jpg',
#  'data\\Cyclone\\630.jpg',
#  'data\\Cyclone\\631.jpg',
#  'data\\Cyclone\\632.jpg',
#  'data\\Cyclone\\633.jpg',
#  'data\\Cyclone\\634.jpg',
#  'data\\Cyclone\\635.jpg',
#  'data\\Cyclone\\636.jpg',
#  'data\\Cyclone\\637.jpg',
#  'data\\Cyclone\\638.jpg',
#  'data\\Cyclone\\639.jpg',
#  'data\\Cyclone\\64.jpg',
#  'data\\Cyclone\\640.jpg',
#  'data\\Cyclone\\641.jpg',
#  'data\\Cyclone\\642.jpg',
#  'data\\Cyclone\\643.jpg',
#  'data\\Cyclone\\644.jpg',
#  'data\\Cyclone\\645.jpg',
#  'data\\Cyclone\\646.jpg',
#  'data\\Cyclone\\647.jpg',
#  'data\\Cyclone\\648.jpg',
#  'data\\Cyclone\\649.jpg',
#  'data\\Cyclone\\65.jpg',
#  'data\\Cyclone\\650.jpg',
#  'data\\Cyclone\\651.jpg',
#  'data\\Cyclone\\652.jpg',
#  'data\\Cyclone\\653.jpg',
#  'data\\Cyclone\\654.jpg',
#  'data\\Cyclone\\655.jpg',
#  'data\\Cyclone\\656.jpg',
#  'data\\Cyclone\\657.jpg',
#  'data\\Cyclone\\658.jpg',
#  'data\\Cyclone\\659.jpg',
#  'data\\Cyclone\\66.jpg',
#  'data\\Cyclone\\660.jpg',
#  'data\\Cyclone\\661.jpg',
#  'data\\Cyclone\\662.jpg',
#  'data\\Cyclone\\663.jpg',
#  'data\\Cyclone\\664.jpg',
#  'data\\Cyclone\\665.jpg',
#  'data\\Cyclone\\666.jpg',
#  'data\\Cyclone\\667.jpg',
#  'data\\Cyclone\\668.jpg',
#  'data\\Cyclone\\669.jpg',
#  'data\\Cyclone\\67.jpg',
#  'data\\Cyclone\\670.jpg',
#  'data\\Cyclone\\671.jpg',
#  'data\\Cyclone\\672.jpg',
#  'data\\Cyclone\\673.jpg',
#  'data\\Cyclone\\674.jpg',
#  'data\\Cyclone\\675.jpg',
#  'data\\Cyclone\\676.jpg',
#  'data\\Cyclone\\677.jpg',
#  'data\\Cyclone\\678.jpg',
#  'data\\Cyclone\\679.jpg',
#  'data\\Cyclone\\68.jpg',
#  'data\\Cyclone\\680.jpg',
#  'data\\Cyclone\\681.jpg',
#  'data\\Cyclone\\682.jpg',
#  'data\\Cyclone\\683.jpg',
#  'data\\Cyclone\\684.jpg',
#  'data\\Cyclone\\685.jpg',
#  'data\\Cyclone\\686.jpg',
#  'data\\Cyclone\\687.jpg',
#  'data\\Cyclone\\688.jpg',
#  'data\\Cyclone\\689.jpg',
#  'data\\Cyclone\\69.jpg',
#  'data\\Cyclone\\690.jpg',
#  'data\\Cyclone\\691.jpg',
#  'data\\Cyclone\\692.jpg',
#  'data\\Cyclone\\693.jpg',
#  'data\\Cyclone\\694.jpg',
#  'data\\Cyclone\\695.jpg',
#  'data\\Cyclone\\696.jpg',
#  'data\\Cyclone\\697.jpg',
#  'data\\Cyclone\\698.jpg',
#  'data\\Cyclone\\699.jpg',
#  'data\\Cyclone\\7.jpg',
#  'data\\Cyclone\\70.jpg',
#  'data\\Cyclone\\700.jpg',
#  'data\\Cyclone\\701.jpg',
#  'data\\Cyclone\\702.jpg',
#  'data\\Cyclone\\703.jpg',
#  'data\\Cyclone\\704.jpg',
#  'data\\Cyclone\\705.jpg',
#  'data\\Cyclone\\706.jpg',
#  'data\\Cyclone\\707.jpg',
#  'data\\Cyclone\\708.jpg',
#  'data\\Cyclone\\709.jpg',
#  'data\\Cyclone\\71.jpg',
#  'data\\Cyclone\\710.jpg',
#  'data\\Cyclone\\711.jpg',
#  'data\\Cyclone\\712.jpg',
#  'data\\Cyclone\\713.jpg',
#  'data\\Cyclone\\714.jpg',
#  'data\\Cyclone\\715.jpg',
#  'data\\Cyclone\\716.jpg',
#  'data\\Cyclone\\717.jpg',
#  'data\\Cyclone\\718.jpg',
#  'data\\Cyclone\\719.jpg',
#  'data\\Cyclone\\72.jpg',
#  'data\\Cyclone\\720.jpg',
#  'data\\Cyclone\\721.jpg',
#  'data\\Cyclone\\722.jpg',
#  'data\\Cyclone\\723.jpg',
#  'data\\Cyclone\\724.jpg',
#  'data\\Cyclone\\725.jpg',
#  'data\\Cyclone\\726.jpg',
#  'data\\Cyclone\\727.jpg',
#  'data\\Cyclone\\728.jpg',
#  'data\\Cyclone\\729.jpg',
#  'data\\Cyclone\\73.jpg',
#  'data\\Cyclone\\730.jpg',
#  'data\\Cyclone\\731.jpg',
#  'data\\Cyclone\\732.jpg',
#  'data\\Cyclone\\733.jpg',
#  'data\\Cyclone\\734.jpg',
#  'data\\Cyclone\\735.jpg',
#  'data\\Cyclone\\736.jpg',
#  'data\\Cyclone\\737.jpg',
#  'data\\Cyclone\\738.jpg',
#  'data\\Cyclone\\739.jpg',
#  'data\\Cyclone\\74.jpg',
#  'data\\Cyclone\\740.jpg',
#  'data\\Cyclone\\741.jpg',
#  'data\\Cyclone\\742.jpg',
#  'data\\Cyclone\\743.jpg',
#  'data\\Cyclone\\744.jpg',
#  'data\\Cyclone\\745.jpg',
#  'data\\Cyclone\\746.jpg',
#  'data\\Cyclone\\747.jpg',
#  'data\\Cyclone\\748.jpg',
#  'data\\Cyclone\\749.jpg',
#  'data\\Cyclone\\75.jpg',
#  'data\\Cyclone\\750.jpg',
#  'data\\Cyclone\\751.jpg',
#  'data\\Cyclone\\752.jpg',
#  'data\\Cyclone\\753.jpg',
#  'data\\Cyclone\\754.jpg',
#  'data\\Cyclone\\755.jpg',
#  'data\\Cyclone\\756.jpg',
#  'data\\Cyclone\\757.jpg',
#  'data\\Cyclone\\758.jpg',
#  'data\\Cyclone\\76.jpg',
#  'data\\Cyclone\\760.jpg',
#  'data\\Cyclone\\761.jpg',
#  'data\\Cyclone\\762.jpg',
#  'data\\Cyclone\\763.jpg',
#  'data\\Cyclone\\764.jpg',
#  'data\\Cyclone\\765.jpg',
#  'data\\Cyclone\\766.jpg',
#  'data\\Cyclone\\767.jpg',
#  'data\\Cyclone\\769.jpg',
#  'data\\Cyclone\\77.jpg',
#  'data\\Cyclone\\771.jpg',
#  'data\\Cyclone\\772.jpg',
#  'data\\Cyclone\\773.jpg',
#  'data\\Cyclone\\774.jpg',
#  'data\\Cyclone\\775.jpg',
#  'data\\Cyclone\\776.jpg',
#  'data\\Cyclone\\777.jpg',
#  'data\\Cyclone\\778.jpg',
#  'data\\Cyclone\\779.jpg',
#  'data\\Cyclone\\78.jpg',
#  'data\\Cyclone\\780.jpg',
#  'data\\Cyclone\\781.jpg',
#  'data\\Cyclone\\782.jpg',
#  'data\\Cyclone\\783.jpg',
#  'data\\Cyclone\\784.jpg',
#  'data\\Cyclone\\785.jpg',
#  'data\\Cyclone\\786.jpg',
#  'data\\Cyclone\\787.jpg',
#  'data\\Cyclone\\788.jpg',
#  'data\\Cyclone\\789.jpg',
#  'data\\Cyclone\\79.jpg',
#  'data\\Cyclone\\790.jpg',
#  'data\\Cyclone\\791.jpg',
#  'data\\Cyclone\\792.jpg',
#  'data\\Cyclone\\793.jpg',
#  'data\\Cyclone\\794.jpg',
#  'data\\Cyclone\\795.jpg',
#  'data\\Cyclone\\796.jpg',
#  'data\\Cyclone\\797.jpg',
#  'data\\Cyclone\\798.jpg',
#  'data\\Cyclone\\799.jpg',
#  'data\\Cyclone\\8.jpg',
#  'data\\Cyclone\\80.jpg',
#  'data\\Cyclone\\800.jpg',
#  'data\\Cyclone\\801.jpg',
#  'data\\Cyclone\\802.jpg',
#  'data\\Cyclone\\803.jpg',
#  'data\\Cyclone\\804.jpg',
#  'data\\Cyclone\\805.jpg',
#  'data\\Cyclone\\806.jpg',
#  'data\\Cyclone\\807.jpg',
#  'data\\Cyclone\\808.jpg',
#  'data\\Cyclone\\809.jpg',
#  'data\\Cyclone\\81.jpg',
#  'data\\Cyclone\\810.jpg',
#  'data\\Cyclone\\811.jpg',
#  'data\\Cyclone\\812.jpg',
#  'data\\Cyclone\\813.jpg',
#  'data\\Cyclone\\814.jpg',
#  'data\\Cyclone\\815.jpg',
#  'data\\Cyclone\\816.jpg',
#  'data\\Cyclone\\817.jpg',
#  'data\\Cyclone\\818.jpg',
#  'data\\Cyclone\\819.jpg',
#  'data\\Cyclone\\82.jpg',
#  'data\\Cyclone\\820.jpg',
#  'data\\Cyclone\\821.jpg',
#  'data\\Cyclone\\822.jpg',
#  'data\\Cyclone\\823.jpg',
#  'data\\Cyclone\\824.jpg',
#  'data\\Cyclone\\825.jpg',
#  'data\\Cyclone\\826.jpg',
#  'data\\Cyclone\\827.jpg',
#  'data\\Cyclone\\828.jpg',
#  'data\\Cyclone\\829.jpg',
#  'data\\Cyclone\\83.jpg',
#  'data\\Cyclone\\830.jpg',
#  'data\\Cyclone\\831.jpg',
#  'data\\Cyclone\\832.jpg',
#  'data\\Cyclone\\833.jpg',
#  'data\\Cyclone\\834.jpg',
#  'data\\Cyclone\\835.jpg',
#  'data\\Cyclone\\836.jpg',
#  'data\\Cyclone\\837.jpg',
#  'data\\Cyclone\\838.jpg',
#  'data\\Cyclone\\839.jpg',
#  'data\\Cyclone\\84.jpg',
#  'data\\Cyclone\\840.jpg',
#  'data\\Cyclone\\841.jpg',
#  'data\\Cyclone\\842.jpg',
#  'data\\Cyclone\\843.jpg',
#  'data\\Cyclone\\844.jpg',
#  'data\\Cyclone\\845.jpg',
#  'data\\Cyclone\\846.jpg',
#  'data\\Cyclone\\847.jpg',
#  'data\\Cyclone\\848.jpg',
#  'data\\Cyclone\\849.jpg',
#  'data\\Cyclone\\85.jpg',
#  'data\\Cyclone\\850.jpg',
#  'data\\Cyclone\\851.jpg',
#  'data\\Cyclone\\852.jpg',
#  'data\\Cyclone\\853.jpg',
#  'data\\Cyclone\\854.jpg',
#  'data\\Cyclone\\855.jpg',
#  'data\\Cyclone\\856.jpg',
#  'data\\Cyclone\\857.jpg',
#  'data\\Cyclone\\858.jpg',
#  'data\\Cyclone\\859.jpg',
#  'data\\Cyclone\\86.jpg',
#  'data\\Cyclone\\860.jpg',
#  'data\\Cyclone\\861.jpg',
#  'data\\Cyclone\\862.jpg',
#  'data\\Cyclone\\863.jpg',
#  'data\\Cyclone\\864.jpg',
#  'data\\Cyclone\\865.jpg',
#  'data\\Cyclone\\866.jpg',
#  'data\\Cyclone\\867.jpg',
#  'data\\Cyclone\\868.jpg',
#  'data\\Cyclone\\869.jpg',
#  'data\\Cyclone\\87.jpg',
#  'data\\Cyclone\\870.jpg',
#  'data\\Cyclone\\871.jpg',
#  'data\\Cyclone\\872.jpg',
#  'data\\Cyclone\\873.jpg',
#  'data\\Cyclone\\874.jpg',
#  'data\\Cyclone\\875.jpg',
#  'data\\Cyclone\\876.jpg',
#  'data\\Cyclone\\877.jpg',
#  'data\\Cyclone\\878.jpg',
#  'data\\Cyclone\\879.jpg',
#  'data\\Cyclone\\88.jpg',
#  'data\\Cyclone\\880.jpg',
#  'data\\Cyclone\\881.jpg',
#  'data\\Cyclone\\882.jpg',
#  'data\\Cyclone\\883.jpg',
#  'data\\Cyclone\\884.jpg',
#  'data\\Cyclone\\885.jpg',
#  'data\\Cyclone\\886.jpg',
#  'data\\Cyclone\\887.jpg',
#  'data\\Cyclone\\888.jpg',
#  'data\\Cyclone\\889.jpg',
#  'data\\Cyclone\\89.jpg',
#  'data\\Cyclone\\890.jpg',
#  'data\\Cyclone\\891.jpg',
#  'data\\Cyclone\\892.jpg',
#  'data\\Cyclone\\893.jpg',
#  'data\\Cyclone\\894.jpg',
#  'data\\Cyclone\\895.jpg',
#  'data\\Cyclone\\896.jpg',
#  'data\\Cyclone\\897.jpg',
#  'data\\Cyclone\\898.jpg',
#  'data\\Cyclone\\899.jpg',
#  'data\\Cyclone\\9.jpg',
#  'data\\Cyclone\\90.jpg',
#  'data\\Cyclone\\900.jpg',
#  'data\\Cyclone\\901.jpg',
#  'data\\Cyclone\\902.jpg',
#  'data\\Cyclone\\903.jpg',
#  'data\\Cyclone\\904.jpg',
#  'data\\Cyclone\\905.jpg',
#  'data\\Cyclone\\906.jpg',
#  'data\\Cyclone\\907.jpg',
#  'data\\Cyclone\\908.jpg',
#  'data\\Cyclone\\909.jpg',
#  'data\\Cyclone\\91.jpg',
#  'data\\Cyclone\\910.jpg',
#  'data\\Cyclone\\911.jpg',
#  'data\\Cyclone\\912.jpg',
#  'data\\Cyclone\\913.jpg',
#  'data\\Cyclone\\914.jpg',
#  'data\\Cyclone\\915.jpg',
#  'data\\Cyclone\\916.jpg',
#  'data\\Cyclone\\917.jpg',
#  'data\\Cyclone\\918.jpg',
#  'data\\Cyclone\\919.jpg',
#  'data\\Cyclone\\92.jpg',
#  'data\\Cyclone\\920.jpg',
#  'data\\Cyclone\\921.jpg',
#  'data\\Cyclone\\922.jpg',
#  'data\\Cyclone\\923.jpg',
#  'data\\Cyclone\\924.jpg',
#  'data\\Cyclone\\925.jpg',
#  'data\\Cyclone\\926.jpg',
#  'data\\Cyclone\\927.jpg',
#  'data\\Cyclone\\928.jpg',
#  'data\\Cyclone\\929.jpg',
#  'data\\Cyclone\\93.jpg',
#  'data\\Cyclone\\930.jpg',
#  'data\\Cyclone\\94.jpg',
#  'data\\Cyclone\\95.jpg',
#  'data\\Cyclone\\96.jpg',
#  'data\\Cyclone\\97.jpg',
#  'data\\Cyclone\\98.jpg',
#  'data\\Cyclone\\99.jpg',
#  'data\\Earthquake\\0.jpg',
#  'data\\Earthquake\\1.jpg',
#  'data\\Earthquake\\10.jpg',
#  'data\\Earthquake\\100.jpg',
#  'data\\Earthquake\\1000.jpg',
#  'data\\Earthquake\\1001.jpg',
#  'data\\Earthquake\\1002.jpg',
#  'data\\Earthquake\\1003.jpg',
#  'data\\Earthquake\\1004.jpg',
#  'data\\Earthquake\\1005.jpg',
#  'data\\Earthquake\\1006.jpg',
#  'data\\Earthquake\\1007.jpg',
#  'data\\Earthquake\\1008.jpg',
#  'data\\Earthquake\\1009.jpg',
#  'data\\Earthquake\\101.jpg',
#  'data\\Earthquake\\1010.jpg',
#  'data\\Earthquake\\1011.jpg',
#  'data\\Earthquake\\1012.jpg',
#  'data\\Earthquake\\1013.jpg',
#  'data\\Earthquake\\1014.jpg',
#  'data\\Earthquake\\1015.jpg',
#  'data\\Earthquake\\1016.jpg',
#  'data\\Earthquake\\1017.jpg',
#  'data\\Earthquake\\1018.jpg',
#  'data\\Earthquake\\1019.jpg',
#  'data\\Earthquake\\102.jpg',
#  'data\\Earthquake\\1020.jpg',
#  'data\\Earthquake\\1021.jpg',
#  'data\\Earthquake\\1022.jpg',
#  'data\\Earthquake\\1023.jpg',
#  'data\\Earthquake\\1024.jpg',
#  'data\\Earthquake\\1025.jpg',
#  'data\\Earthquake\\1026.jpg',
#  'data\\Earthquake\\1027.jpg',
#  'data\\Earthquake\\1028.jpg',
#  'data\\Earthquake\\1029.jpg',
#  'data\\Earthquake\\103.jpg',
#  'data\\Earthquake\\1030.jpg',
#  'data\\Earthquake\\1031.jpg',
#  'data\\Earthquake\\1032.jpg',
#  'data\\Earthquake\\1033.jpg',
#  'data\\Earthquake\\1034.jpg',
#  'data\\Earthquake\\1035.jpg',
#  'data\\Earthquake\\1036.jpg',
#  'data\\Earthquake\\1037.jpg',
#  'data\\Earthquake\\1038.jpg',
#  'data\\Earthquake\\1039.jpg',
#  'data\\Earthquake\\104.jpg',
#  'data\\Earthquake\\1040.jpg',
#  'data\\Earthquake\\1041.jpg',
#  'data\\Earthquake\\1042.jpg',
#  'data\\Earthquake\\1043.jpg',
#  'data\\Earthquake\\1044.jpg',
#  'data\\Earthquake\\1045.jpg',
#  'data\\Earthquake\\1046.jpg',
#  'data\\Earthquake\\1047.jpg',
#  'data\\Earthquake\\1048.jpg',
#  'data\\Earthquake\\1049.jpg',
#  'data\\Earthquake\\105.jpg',
#  'data\\Earthquake\\1050.jpg',
#  'data\\Earthquake\\1051.jpg',
#  'data\\Earthquake\\1052.jpg',
#  'data\\Earthquake\\1053.jpg',
#  'data\\Earthquake\\1054.jpg',
#  'data\\Earthquake\\1055.jpg',
#  'data\\Earthquake\\1056.jpg',
#  'data\\Earthquake\\1057.jpg',
#  'data\\Earthquake\\1058.jpg',
#  'data\\Earthquake\\1059.jpg',
#  'data\\Earthquake\\106.jpg',
#  'data\\Earthquake\\1060.jpg',
#  'data\\Earthquake\\1061.jpg',
#  ...]

# %%
os.mkdir(os.path.join(path, 'train'))
os.mkdir(os.path.join(path, 'valid'))
os.mkdir(os.path.join(path, 'test'))

# %%
rand_shuffle = np.random.permutation(len(files))

# %%
for _f in ['train', 'valid', 'test']:
    for _fold in os.listdir(path):
        os.mkdir(os.path.join(path, _f, _fold))

# %%
len(rand_shuffle)
# Out:
# 4428

# %%
(len(files)*0.2)
# Out:
# 885.6

# %%
for n in rand_shuffle[:88]:
    folder = files[n].split('\\')[1]
    name = files[n].split('\\')[-1]
    os.rename(files[n], os.path.join(path, 'valid', folder, name))

# %%
for n in rand_shuffle[88:700]:
    folder = files[n].split('\\')[1]
    name = files[n].split('\\')[-1]
    os.rename(files[n], os.path.join(path, 'test', folder, name))

# %%
for n in rand_shuffle[700:]:
    folder = files[n].split('\\')[1]
    name = files[n].split('\\')[-1]
    os.rename(files[n], os.path.join(path, 'train', folder, name))

# %%
os.rmdir('data/train/train')
os.rmdir('data/train/test')
os.rmdir('data/test/test')
os.rmdir('data/test/train')
os.rmdir('data/valid/test')
os.rmdir('data/valid/train')
os.rmdir('data/test/valid')
os.rmdir('data/train/valid')
os.rmdir('data/valid/valid')

# %%
train_dir = 'data/train'
valid_dir = 'data/valid/'
test_dir = 'data/test'

# %%
training_dataloader, testing_dataloader, class_names = create_dataloaders(train_dir=train_dir, test_dir=test_dir, valid_dir=valid_dir, batch_size=16, num_workers=os.cpu_count(), transform=transform)

# %%
print(class_names)
# Out:
# ['Cyclone', 'Earthquake', 'Flood', 'Wildfire']

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    # plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

def show_databatch(inputs, classes):
    out = torchvision.utils.make_grid(inputs)
    imshow(out, title=[class_names[x] for x in classes])

# Get a batch of training data
inputs, classes = next(iter(training_dataloader))
show_databatch(inputs, classes)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for params in model.features.parameters():
    params.requires_grad=False


num_features = model.classifier[6].in_features
features = list(model.classifier.children())[:-1]
features.extend([nn.Linear(num_features, len(class_names))])
model.classifier = nn.Sequential(*features)

# %%
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )

# %%
from ast import Dict, List, Tuple


def training_step(model: torch.nn.Module,
                  dataloader: torch.utils.data.DataLoader,
                  loss_fn: torch.nn.Module,
                  optimizer: torch.optim.Optimizer):
    model.train()
    train_loss, train_acc = 0, 0
    
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.cuda(), y.cuda()
        y_pred = model(X)
        loss = loss_fn(y_pred, y)
        train_loss += loss.cpu().item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc
def test_step(model: torch.nn.Module, 
              dataloader: torch.utils.data.DataLoader, 
              loss_fn: torch.nn.Module):

    model.eval() 
    test_loss, test_acc = 0, 0

    with torch.inference_mode():
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.cuda(), y.cuda()
            test_pred_logits = model(X)
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.cpu().item()
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

def train(model: torch.nn.Module, 
          train_dataloader: torch.utils.data.DataLoader, 
          test_dataloader: torch.utils.data.DataLoader, 
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int):
  
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }

    model.cuda()

    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = training_step(model=model,
                                          dataloader=train_dataloader,
                                          loss_fn=loss_fn,
                                          optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
          dataloader=test_dataloader,
          loss_fn=loss_fn)

        print(
          f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
        )

        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    return results

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

results = train(model=model, 
                       train_dataloader=training_dataloader,
                       test_dataloader=testing_dataloader, 
                       epochs=20, 
                       loss_fn=loss_fn, 
                       optimizer=optimizer)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.3053 | train_acc: 0.8948 | test_loss: 0.1118 | test_acc: 0.9674
# Epoch: 2 | train_loss: 0.1699 | train_acc: 0.9415 | test_loss: 0.0986 | test_acc: 0.9629
# Epoch: 3 | train_loss: 0.1249 | train_acc: 0.9540 | test_loss: 0.1104 | test_acc: 0.9629
# Epoch: 4 | train_loss: 0.0968 | train_acc: 0.9670 | test_loss: 0.0835 | test_acc: 0.9629
# Epoch: 5 | train_loss: 0.0825 | train_acc: 0.9702 | test_loss: 0.0734 | test_acc: 0.9719
# Epoch: 6 | train_loss: 0.0587 | train_acc: 0.9815 | test_loss: 0.0724 | test_acc: 0.9652
# Epoch: 7 | train_loss: 0.0565 | train_acc: 0.9778 | test_loss: 0.0642 | test_acc: 0.9732
# Epoch: 8 | train_loss: 0.0474 | train_acc: 0.9840 | test_loss: 0.0781 | test_acc: 0.9719
# Epoch: 9 | train_loss: 0.0398 | train_acc: 0.9862 | test_loss: 0.0757 | test_acc: 0.9696
# Epoch: 10 | train_loss: 0.0297 | train_acc: 0.9910 | test_loss: 0.0795 | test_acc: 0.9696
# Epoch: 11 | train_loss: 0.0504 | train_acc: 0.9888 | test_loss: 0.0825 | test_acc: 0.9754
# Epoch: 12 | train_loss: 0.0348 | train_acc: 0.9868 | test_loss: 0.0718 | test_acc: 0.9719
# Epoch: 13 | train_loss: 0.0301 | train_acc: 0.9890 | test_loss: 0.0734 | test_acc: 0.9719
# Epoch: 14 | train_loss: 0.0280 | train_acc: 0.9910 | test_loss: 0.0795 | test_acc: 0.9674
# Epoch: 15 | train_loss: 0.0143 | train_acc: 0.9970 | test_loss: 0.0768 | test_acc: 0.9688
# Epoch: 16 | train_loss: 0.0202 | train_acc: 0.9932 | test_loss: 0.0798 | test_acc: 0.9674
# Epoch: 17 | train_loss: 0.0190 | train_acc: 0.9935 | test_loss: 0.0857 | test_acc: 0.9719
# Epoch: 18 | train_loss: 0.0187 | train_acc: 0.9942 | test_loss: 0.0813 | test_acc: 0.9674
# Epoch: 19 | train_loss: 0.0124 | train_acc: 0.9970 | test_loss: 0.0799 | test_acc: 0.9674
# Epoch: 20 | train_loss: 0.0166 | train_acc: 0.9938 | test_loss: 0.0785 | test_acc: 0.9674

# %%
from matplotlib import pyplot as plt


def plot_loss_curves(results):

    loss = results["train_loss"]
    test_loss = results["test_loss"]

    accuracy = results["train_acc"]
    test_accuracy = results["test_acc"]

    epochs = range(len(results["train_loss"]))

    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label="train_loss")
    plt.plot(epochs, test_loss, label="test_loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label="train_accuracy")
    plt.plot(epochs, test_accuracy, label="test_accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.legend()

# %%
plot_loss_curves(results=results)

# %%
def visualize_model(vgg, num_images=6):
    was_training = vgg.training
    
    # Set model for evaluation
    vgg.train(False)
    vgg.eval() 
    
    images_so_far = 0

    for i, data in enumerate(testing_dataloader):
        inputs, labels = data
        size = inputs.size()[0]
        
        if torch.cuda.is_available():
            inputs, labels = inputs.cuda(), labels.cuda()
        else:
            inputs, labels = inputs, labels
        
        outputs = vgg(inputs)
        
        _, preds = torch.max(outputs.data, 1)
        predicted_labels = [preds[j] for j in range(inputs.size()[0])]
        
        print("Ground truth:")
        show_databatch(inputs.data.cpu(), labels.data.cpu())
        print("Prediction:")
        show_databatch(inputs.data.cpu(), predicted_labels)
        
        del inputs, labels, outputs, preds, predicted_labels
        torch.cuda.empty_cache()
        
        images_so_far += size
        if images_so_far >= num_images:
            break
        
    vgg.train(mode=was_training)

# %%
visualize_model(model)
# Out:
# Ground truth:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Prediction:
